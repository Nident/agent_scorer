# %%
import json
from pprint import pprint

path = "/Users/nident/Desktop/JOB/startup/agent_scorer/data/simple_model_response_20260427_175824.json"

with open(path, "r", encoding="utf-8") as f:
    data = json.load(f)

pprint(data)
# Out:
# {'blocks': [{'block_index': 1,
#              'dialogue_block': 'B: The Parma trolleybus system (Italian: "Rete '
#                                'filoviaria di Parma" ) forms part of the '
#                                'public transport network of the city and '
#                                '"comune" of Parma, in the region of '
#                                'Emilia-Romagna, northern Italy. In operation '
#                                'since 1953, the system presently comprises '
#                                'four urban routes.',
#              'dialogue_history': '',
#              'prompt': 'You are a negotiation quality judge.\n'
#                        '\n'
#                        'Your task is to score one negotiation criterion for '
#                        'the evaluated speaker.\n'
#                        '\n'
#                        'Think step by step internally, but do not output '
#                        'hidden reasoning.\n'
# ...

# %%
resp = json.loads(data['final']['raw_response'])
pprint(resp['points'])
# Out:
# [{'confidence': 1.0,
#   'point': 'The trolleybus system has over 2 urban routes',
#   'quote': 'the system presently comprises four urban routes',
#   'rationale': 'B states the system has four urban routes, which is over 2.',
#   'score': 1},
#  {'confidence': 0.9,
#   'point': 'Since 1953 the Parma Troleybus system has been comprised of four '
#            'urban routes.',
#   'quote': '',
#   'rationale': 'B says the system has been in operation since 1953 and '
#                'presently comprises four routes, but does not state that it '
#                'has been comprised of four routes since 1953.',
#   'score': 0},
#  {'confidence': 1.0,
#   'point': 'The Parma trolleybus was widely used in the 1940s.',
#   'quote': 'In operation since 1953',
#   'rationale': 'B states the system started in 1953, contradicting the claim '
#                'that it was widely used in the 1940s.',
#   'score': -1}]
